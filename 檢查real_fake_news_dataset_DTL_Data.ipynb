# %% [markdown]
# # import tool

# %%
import os
import json

# %%
os.listdir("./real_fake_news_dataset")
# Out:
# ['DTL_Data', 'GoogleFactCheck']

# %%
# DTL_Data

# %%
os.listdir("./real_fake_news_dataset/DTL_Data")
# Out:
# ['動物傳染病.json',
#  '美豬.json',
#  '罷免.json',
#  '颱風.json',
#  '病毒.json',
#  '食品衛生.json',
#  '傳染病.json',
#  '飛機.json',
#  '救災.json',
#  '農產品價格.json',
#  '豬肉.json',
#  '農產品.json']

# %%
with open("./real_fake_news_dataset/DTL_Data/%s" % '動物傳染病.json') as json_file:
    data = json.load(json_file)

# %%
# for file in os.listdir("./real_fake_news_dataset/DTL_Data"):
#     with

# %%
list(data.keys())
# Out:
# ['download', 'params', 'count', 'posts_by_date']

# %%
for post in data['posts_by_date']:
    title = post["text"]
    body =
# Out:
#   File "<ipython-input-47-812dcd765b9d>", line 3
#     body =
#            ^
# SyntaxError: invalid syntax

# %%
data_posts_by_date = data['posts_by_date']

# %%
data_posts_by_date
# Out:
# [{'id': '5620733654784-rumor',
#   'text': '《風傳媒》早餐改喝這個吧！日本重大發現：這隨處可見的飲料，竟是對抗諾羅病毒的良藥 | http://www.storm.mg/lifestyle/211316',
#   'createdAt': '2017-02-09T02:01:00.000Z',
#   'updatedAt': '2017-02-09T02:01:00.000Z',
#   'hyperlinks': [{'url': 'http://www.storm.mg/lifestyle/211316'}],
#   'articleReplies': [{'reply': {'id': 'AVvOrwMPyCdS-nWhuYSp',
#      'text': '日本靜岡縣環境研究所發現紅茶裡的一種酚類化合物－茶黃素（Theaflavins），能抑制諾羅病毒感染動物細胞，也是科學史上第一次證實茶黃素具有抗病毒效果的研究，研究發表在國際期刊《The Journal of Antibiotic》。',
#      'type': 'NOT_RUMOR',
#      'reference': 'https://www.thenewslens.com/article/58312\n關鍵評論網 諾羅病毒，不用怕！喝紅茶就對了'}}]},
#  {'id': '5648260550147-rumor',
#   'text': 'http://blog.xuite.net/tonycjones/twblog/483450040',
#   'createdAt': '2017-02-14T17:23:00.000Z',
#   'updatedAt': '2017-02-14T17:23:00.000Z',
#   'hyperlinks': [{'url': 'http://blog.xuite.net/tonycjones/twblog/483450040'}],
#   'articleReplies': [{'reply': {'id': 'AVvxQpSpyCdS-nWhuYsD',
#      'text': ' 疑似為訊息之節錄片段，並非全文。',
# ...
